# %%
import pandas as pd

# %%
x = pd.ExcelFile("evaluation tool.xlsm")
s = x.sheet_names[1]
p = x.parse(s)
t= p.drop(p.columns[[0, 1, 2, 3, 4, 5, 6, 7]], axis = 1)
t.drop(p.index[0:2])
# Out:
#     EVALUATOR 1  Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 2            NaN          A           B           C           D           E
# 3              A        NaN          B2          A3          D2          A3
# 4              B        NaN         NaN          B2          D2          B2
# 5              C        NaN         NaN         NaN          D4          E3
# 6              D        NaN         NaN         NaN         NaN          D2
# ..           ...        ...         ...         ...         ...         ...
# 128            F        NaN         NaN         NaN         NaN         NaN
# 129            G        NaN         NaN         NaN         NaN         NaN
# 130            H        NaN         NaN         NaN         NaN         NaN
# 131            I        NaN         NaN         NaN         NaN         NaN
# 132            L        NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
a
