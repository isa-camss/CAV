# %% [markdown]
# <h1 align="center">ELECTRE METHOD - PHASE I SHOW</h1>

# %% [markdown]
# <h3>This notebook illustrates how the <b>ELECTRE-II</b> method is used to rank the best tenders for one Procurement Procedure Lot.</h3>
#
# The algorithm followed for this goes as follows:
#
# 1. Extract data from an Excel file containing the comparative values assigned by 3 evaluators to a set of Quality AwardCriteria
# 2. Transform the extracted data into a Graph compliant with the CAV-Anticorrupzione-Application Profile TBox
# 3. Load the data in a Graph Store
# 4. Query the Graph Store to retrieve the data
# 5. Rank the tender-lots

# %%
import etl
import sparql as q
import store
import electre

# %% [markdown]
# <h2> Step #1: Extraction of the data from the excel file</h2>

# %%
EXCEL_FILE = 'evaluation-tool.xlsm'
DATA_TAB = 'REPORTS PER EVALUATOR'
CRITERIA_TAB = 'MAIN REPORT'
g = etl.graph()  # Creates the graph of the ABox
g, criteria = etl.instantiate_criteria(g, EXCEL_FILE, CRITERIA_TAB)
e = etl.extract(EXCEL_FILE, DATA_TAB)           # Creates a pandas data frame from the Excel dataset

# %% [markdown]
# <h4>Here you have an overview of the data in a pandas' data frame:</h4>

# %%
print(e)
# Out:
#                        C8 E1 E1.A E1.B E1.C E1.D E1.E E1.F E1.G E1.H  ...  \
# 4     1. Quality aspect 1  A  NaN   B2   A3   D2   A3   A2   A3   H2  ...
# 5     1. Quality aspect 1  B  NaN  NaN   B2   D2   B2   B2   B3    1  ...
# 6     1. Quality aspect 1  C  NaN  NaN  NaN   D4   E3   F3   G2   H4  ...
# 7     1. Quality aspect 1  D  NaN  NaN  NaN  NaN   D2   D3   D4   D2  ...
# 8     1. Quality aspect 1  E  NaN  NaN  NaN  NaN  NaN   E2   E3   H2  ...
# ..                    ... ..  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 129  1. Quality aspect 11  F  NaN  NaN  NaN  NaN  NaN  NaN   F5   F3  ...
# 130  1. Quality aspect 11  G  NaN  NaN  NaN  NaN  NaN  NaN  NaN   H3  ...
# 131  1. Quality aspect 11  H  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 132  1. Quality aspect 11  I  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 133  1. Quality aspect 11  L  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
#
#     E3.A E3.B E3.C E3.D E3.E E3.F E3.G E3.H E3.I E3.L
# 4    NaN   B3   A3   D3   E2   F3   A5   H2   I2   A3
# 5    NaN  NaN   B3   D2    1    1   B3    1    1   B5
# 6    NaN  NaN  NaN   D5   E3   F3    1   H3   I3    1
# 7    NaN  NaN  NaN  NaN   D2   D2   D3   D2   D2   D5
# 8    NaN  NaN  NaN  NaN  NaN    1   E5    1    1   E5
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 129  NaN  NaN  NaN  NaN  NaN  NaN   F3    1    1   F2
# 130  NaN  NaN  NaN  NaN  NaN  NaN  NaN   H3   I3   L2
# 131  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    1   H2
# 132  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   I2
# 133  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [130 rows x 34 columns]

# %% [markdown]
# <h2>Step #2: Creation of the CAV-AC-AP ABox</h2>

# %%
g, r = etl.build_roles(g)                       # Instantiates the role 'evaluator'
g, tl = etl.lots_tendered(g)                    # Instantiates TenderLots 'A' to 'L'
g = etl.transform(e, g, tl, r, criteria)        # Populates the graph

# %% [markdown]
# <h4>The results have been extracted into a file named 'a-box.ttl'. Here you have the contents (it's a long process, since it generates many triples, so you will have to wait a short while):</h4>

# %%
etl.show_save(g, True)
# Out:
# @prefix cap: <http://data.europa.eu/w21/2c930c7b-5e2f-4954-8522-bd3411339d6c/extension/cap#> .
# @prefix cccev: <https://data.europe.eu/semanticassets/ns/cv/cccev_v2.0.0#> .
# @prefix ct: <http://data.europa.eu/w21/2c930c7b-5e2f-4954-8522-bd3411339d6c/resource/criterion-type#> .
# @prefix cv: <http://data.europa.eu/m8g#> .
# @prefix epo: <http://data.europa.eu/a4g/ontology#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix roles: <http://data.europa.eu/w21/2c930c7b-5e2f-4954-8522-bd3411339d6c/resource/role-type#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# cap:A-tender-lot-daeb073d-badd-4697-a57b-3f15c97a34e8 a epo:TenderLot,
#         owl:NamedIndividual ;
#     epo:relatesTo epo:Lot1 .
#
# cap:B-tender-lot-2baf9585-ceff-41b7-bf5f-954c516a888b a epo:TenderLot,
#         owl:NamedIndividual ;
#     epo:relatesTo epo:Lot1 .
#
# cap:C-tender-lot-6f1aaa25-a96a-4bbf-93ac-caae7153b3df a epo:TenderLot,
#         owl:NamedIndividual ;
#     epo:relatesTo epo:Lot1 .
#
# cap:D-tender-lot-a27bbeec-1391-46f6-b0b5-a00156f50964 a epo:TenderLot,
#         owl:NamedIndividual ;
#     epo:relatesTo epo:Lot1 .
#
# cap:E-tender-lot-2d2ad808-ed3b-44a3-8f92-67e706d48801 a epo:TenderLot,
#         owl:NamedIndividual ;
#     epo:relatesTo epo:Lot1 .
#
# cap:F-tender-lot-1921a860-c586-43fb-9de2-5251ace6fb7c a epo:TenderLot,
#         owl:NamedIndividual ;
#     epo:relatesTo epo:Lot1 .
#
# cap:G-tender-lot-59ce04a1-3479-41f6-953d-4651587c67d9 a epo:TenderLot,
#         owl:NamedIndividual ;
#     epo:relatesTo epo:Lot1 .
#
# cap:H-tender-lot-3596aa03-28ed-4c3d-a10b-85658448bdb5 a epo:TenderLot,
#         owl:NamedIndividual ;
#     epo:relatesTo epo:Lot1 .
#
# cap:I-tender-lot-9769aec8-bf4d-404b-9e46-bed0b670f5a5 a epo:TenderLot,
#         owl:NamedIndividual ;
#     epo:relatesTo epo:Lot1 .
#
# cap:L-tender-lot-15ebda45-44b6-4262-bfe4-fcd1f40ccc62 a epo:TenderLot,
#         owl:NamedIndividual ;
#     epo:relatesTo epo:Lot1 .
#
# cap:input-value-0015c588-d3d1-483c-a670-7072a065fdba a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "I" ;
#     cap:comparesWithTargetThing "I" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-7c2ad08a1d9dc8fe65ea391c85cab251 .
#
# cap:input-value-004efcec-c048-4021-a479-f82acd9eb470 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "H" ;
#     cap:comparesWithTargetThing "H" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-7c2ad08a1d9dc8fe65ea391c85cab251 .
#
# cap:input-value-00516e5c-132a-4413-8a17-460d5c7d08ca a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "G" ;
#     cap:comparesWithTargetThing "A" ;
#     cap:hasBetterCandidate "even" ;
#     cap:hasNumericValue 1 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-8ead6d82f482ea5d21db66d8d7f3a191 .
#
# cap:input-value-007eb9d7-1043-4cb2-923f-7c0305365981 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "A" ;
#     cap:comparesWithTargetThing "E" ;
#     cap:hasBetterCandidate "even" ;
#     cap:hasNumericValue 1 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-46352a35695b0cfd4ae8567d527b022d .
#
# cap:input-value-008d3c10-741d-4e17-bd5e-42bcf90cd0fd a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "L" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-922c7f0e2ad6e08a1d13462b288670ed .
#
# cap:input-value-008e1f20-7ef8-4b44-a345-961ca94da368 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "H" ;
#     cap:comparesWithTargetThing "H" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-46352a35695b0cfd4ae8567d527b022d .
#
# cap:input-value-00b3d480-ab29-4986-9a77-92f3b387582e a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "E" ;
#     cap:comparesWithTargetThing "E" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-8ead6d82f482ea5d21db66d8d7f3a191 .
#
# cap:input-value-00c9bcd0-2401-4a92-ae85-16c2a5a293df a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "L" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-a5933ae077ded5cd0659969993afe4f0 .
#
# cap:input-value-00d71d58-68f0-40a5-bbb6-ea6a75ca73d6 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "E" ;
#     cap:comparesWithTargetThing "E" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-46352a35695b0cfd4ae8567d527b022d .
#
# cap:input-value-00daf83b-a702-42e3-9b0c-4728ccf9bb44 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "E" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "E" ;
#     cap:hasNumericValue 3 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-131d62d76f82880345bfb89aa8d8473b .
#
# cap:input-value-00e911ce-d6e9-4647-9622-b3496e31cc63 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "E" ;
#     cap:comparesWithTargetThing "E" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-e1c920f35ae87bdd2146058625b6866c .
#
# cap:input-value-011e6ac3-f458-44db-b35e-33a32b1054a2 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "D" ;
#     cap:comparesWithTargetThing "D" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-33cc17b2ef1c119ec68af325ba1f5aab .
#
# cap:input-value-012a101c-cf1d-4201-aa35-6424feacebef a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "B" ;
#     cap:comparesWithTargetThing "B" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-46d5b36249c0e5b4e9f4e2f7ef7ecaee .
#
# cap:input-value-012c174d-b203-4585-9b87-ead987250716 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "D" ;
#     cap:comparesWithTargetThing "G" ;
#     cap:hasBetterCandidate "D" ;
#     cap:hasNumericValue 3 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-8ead6d82f482ea5d21db66d8d7f3a191 .
#
# cap:input-value-013a046d-0061-44ef-bf29-b3be363874cd a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "G" ;
#     cap:comparesWithTargetThing "G" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-46d5b36249c0e5b4e9f4e2f7ef7ecaee .
#
# cap:input-value-01487ec9-248e-4d58-a78e-b95a1801f26e a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "B" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "B" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-a5933ae077ded5cd0659969993afe4f0 .
#
# cap:input-value-01794af2-4a38-4451-9a02-deda2053ff8d a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "F" ;
#     cap:comparesWithTargetThing "F" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-33cc17b2ef1c119ec68af325ba1f5aab .
#
# cap:input-value-017ae078-856f-4b2a-92f8-f0f85011101c a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "E" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "even" ;
#     cap:hasNumericValue 1 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-46352a35695b0cfd4ae8567d527b022d .
#
# cap:input-value-0183b20a-2a75-4210-8689-035316d05060 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "F" ;
#     cap:comparesWithTargetThing "F" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-33cc17b2ef1c119ec68af325ba1f5aab .
#
# cap:input-value-0196a524-b017-47a3-9a25-f46af7d7700a a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "L" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-33cc17b2ef1c119ec68af325ba1f5aab .
#
# cap:input-value-01cb8e43-477e-443a-8efd-7aa48f505be5 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "A" ;
#     cap:comparesWithTargetThing "A" ;
#     cap:hasBetterCandidate "A" ;
#     cap:hasNumericValue 3 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-57b127bb2f81913bbddead0094b4438e .
#
# cap:input-value-01e2a142-8148-425e-bce5-90345a8a9df2 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "D" ;
#     cap:comparesWithTargetThing "E" ;
#     cap:hasBetterCandidate "D" ;
#     cap:hasNumericValue 3 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-a5933ae077ded5cd0659969993afe4f0 .
#
# cap:input-value-01fb8019-3b69-4d61-b202-1094ca41ff90 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "F" ;
#     cap:comparesWithTargetThing "F" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-8ead6d82f482ea5d21db66d8d7f3a191 .
#
# cap:input-value-0205edf1-8657-4c9a-81b5-8a1b73e611df a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "B" ;
#     cap:comparesWithTargetThing "B" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-46352a35695b0cfd4ae8567d527b022d .
#
# cap:input-value-020f4d0f-b031-4f2d-8419-e23350187bf6 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "F" ;
#     cap:comparesWithTargetThing "B" ;
#     cap:hasBetterCandidate "F" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-8ead6d82f482ea5d21db66d8d7f3a191 .
#
# cap:input-value-020fe317-984e-4bcc-b9b3-cd83243cd0ca a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "G" ;
#     cap:comparesWithTargetThing "G" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-7c2ad08a1d9dc8fe65ea391c85cab251 .
#
# cap:input-value-0219380e-2ee2-4bf9-ac89-778e4fa04db4 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "L" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-7c2ad08a1d9dc8fe65ea391c85cab251 .
#
# cap:input-value-024fa40b-32af-4a0e-ac52-b19e78e9f4ba a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "F" ;
#     cap:comparesWithTargetThing "F" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-e1c920f35ae87bdd2146058625b6866c .
#
# cap:input-value-0265f897-68c3-425b-ad54-4095f50ba343 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "B" ;
#     cap:comparesWithTargetThing "H" ;
#     cap:hasBetterCandidate "B" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-33cc17b2ef1c119ec68af325ba1f5aab .
#
# cap:input-value-0289c90e-f4ea-4f1d-9b39-971230b0f0a6 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "F" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "L" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-57b127bb2f81913bbddead0094b4438e .
#
# cap:input-value-02b5fd60-af8d-48d6-b256-462b4fc79d24 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "L" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-a5933ae077ded5cd0659969993afe4f0 .
#
# cap:input-value-02c0ad60-fdc5-46cb-b599-033b3b779137 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "D" ;
#     cap:comparesWithTargetThing "D" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-46d5b36249c0e5b4e9f4e2f7ef7ecaee .
#
# cap:input-value-02c318e8-b08a-4f2c-be4b-d4e8f4021748 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "C" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "I" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-131d62d76f82880345bfb89aa8d8473b .
#
# cap:input-value-02c498c4-08bb-4921-a431-103efe01e128 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "L" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-57b127bb2f81913bbddead0094b4438e .
#
# cap:input-value-02e187b2-d862-4b12-9e16-88809a041296 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "D" ;
#     cap:comparesWithTargetThing "G" ;
#     cap:hasBetterCandidate "D" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-46d5b36249c0e5b4e9f4e2f7ef7ecaee .
#
# cap:input-value-02e6ce4a-8000-4b3d-86e1-36fa1a103e7d a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "H" ;
#     cap:comparesWithTargetThing "H" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-7c2ad08a1d9dc8fe65ea391c85cab251 .
#
# cap:input-value-03008252-ac9a-47f7-a9f8-d9fe39c53938 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "D" ;
#     cap:comparesWithTargetThing "H" ;
#     cap:hasBetterCandidate "D" ;
#     cap:hasNumericValue 3 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-a5933ae077ded5cd0659969993afe4f0 .
#
# cap:input-value-030fed74-ae95-4407-b5d5-c23862c478b5 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "I" ;
#     cap:comparesWithTargetThing "A" ;
#     cap:hasBetterCandidate "I" ;
#     cap:hasNumericValue 3 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-e1c920f35ae87bdd2146058625b6866c .
#
# cap:input-value-035c9274-2c70-4c70-a1e5-720066b44c81 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "H" ;
#     cap:comparesWithTargetThing "H" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-7c2ad08a1d9dc8fe65ea391c85cab251 .
#
# cap:input-value-036ff325-2312-4a90-9b21-0cf865a712de a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "I" ;
#     cap:comparesWithTargetThing "I" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-a5933ae077ded5cd0659969993afe4f0 .
#
# cap:input-value-03873f07-0b54-47ef-8833-bfe6d5a9232e a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "F" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "F" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-33cc17b2ef1c119ec68af325ba1f5aab .
#
# cap:input-value-03c2b1c0-68df-4b65-ba25-55db2042e3f8 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "L" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-f365b3d88b69c6f7bdde5b94dfc8d518 .
#
# cap:input-value-03c404d3-489a-47c8-be0d-afef54978271 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "G" ;
#     cap:comparesWithTargetThing "G" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-131d62d76f82880345bfb89aa8d8473b .
#
# cap:input-value-03cd8359-7365-47d8-84c3-2e566bd45f73 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "B" ;
#     cap:comparesWithTargetThing "B" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-7c2ad08a1d9dc8fe65ea391c85cab251 .
#
# cap:input-value-03e79f1b-4296-4104-acd4-19eac3de2ff6 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "E" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "E" ;
#     cap:hasNumericValue 3 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-7c2ad08a1d9dc8fe65ea391c85cab251 .
#
# cap:input-value-03f706b5-4308-4054-b4bf-d9861e91a13f a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "L" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-46d5b36249c0e5b4e9f4e2f7ef7ecaee .
#
# cap:input-value-040afe39-26f3-463b-b34a-6145ef42e487 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "B" ;
#     cap:comparesWithTargetThing "B" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-46352a35695b0cfd4ae8567d527b022d .
#
# cap:input-value-0425c822-9648-4899-8290-31fac86ef488 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "F" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "H" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-7c2ad08a1d9dc8fe65ea391c85cab251 .
#
# cap:input-value-0481ec0a-7ba9-4586-975e-cdb8cd047c26 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "B" ;
#     cap:comparesWithTargetThing "G" ;
#     cap:hasBetterCandidate "F" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-46d5b36249c0e5b4e9f4e2f7ef7ecaee .
#
# cap:input-value-0494372d-a913-4b2f-9528-11bdce6be59a a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "E" ;
#     cap:comparesWithTargetThing "E" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-7c2ad08a1d9dc8fe65ea391c85cab251 .
#
# cap:input-value-04945734-a69f-4cb6-bfb3-c3f590638960 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "C" ;
#     cap:comparesWithTargetThing "E" ;
#     cap:hasBetterCandidate "E" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-131d62d76f82880345bfb89aa8d8473b .
#
# cap:input-value-049bf7b8-1743-4406-86ee-23e40e44cac1 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "A" ;
#     cap:comparesWithTargetThing "A" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-46d5b36249c0e5b4e9f4e2f7ef7ecaee .
#
# cap:input-value-049f8c84-b361-4b21-90ec-b04be48ffb76 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "G" ;
#     cap:comparesWithTargetThing "G" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-922c7f0e2ad6e08a1d13462b288670ed .
#
# cap:input-value-04b44d85-c338-4f4e-bb4b-f74419d548bb a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "H" ;
#     cap:comparesWithTargetThing "H" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-f365b3d88b69c6f7bdde5b94dfc8d518 .
#
# cap:input-value-04bf1212-2841-4344-becd-a95e766b5246 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "H" ;
#     cap:comparesWithTargetThing "H" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-131d62d76f82880345bfb89aa8d8473b .
#
# cap:input-value-04c2c16e-9ac7-4948-a9df-b1acf35550fe a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "L" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-46d5b36249c0e5b4e9f4e2f7ef7ecaee .
#
# cap:input-value-04d44b02-4459-45b3-b7d6-50b74c658dab a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "H" ;
#     cap:comparesWithTargetThing "H" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-131d62d76f82880345bfb89aa8d8473b .
#
# cap:input-value-04f1d730-91ed-45ce-8a21-37331632c826 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "B" ;
#     cap:comparesWithTargetThing "G" ;
#     cap:hasBetterCandidate "B" ;
#     cap:hasNumericValue 6 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-a5933ae077ded5cd0659969993afe4f0 .
#
# cap:input-value-04f2bbde-445d-46f2-a5a4-922634eaf4ce a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "H" ;
#     cap:comparesWithTargetThing "H" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-131d62d76f82880345bfb89aa8d8473b .
#
# cap:input-value-050c4388-c90c-47db-86d6-3a7c6b0b34dd a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "C" ;
#     cap:comparesWithTargetThing "C" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-7c2ad08a1d9dc8fe65ea391c85cab251 .
#
# cap:input-value-05263efb-c5de-4594-93f2-6729e641978a a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "I" ;
#     cap:comparesWithTargetThing "I" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-7c2ad08a1d9dc8fe65ea391c85cab251 .
#
# cap:input-value-053b7ef3-b8ce-474f-9028-04c23906e815 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "I" ;
#     cap:comparesWithTargetThing "I" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-57b127bb2f81913bbddead0094b4438e .
#
# cap:input-value-0549c943-38d0-4a42-9c14-ac39c38798b9 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "F" ;
#     cap:comparesWithTargetThing "F" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-33cc17b2ef1c119ec68af325ba1f5aab .
#
# cap:input-value-054bfe94-d317-427c-a9c4-00e2b9abe53b a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "I" ;
#     cap:comparesWithTargetThing "I" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-7c2ad08a1d9dc8fe65ea391c85cab251 .
#
# cap:input-value-055be485-e3ca-453c-bd74-37fcd3569ccb a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "G" ;
#     cap:comparesWithTargetThing "G" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-922c7f0e2ad6e08a1d13462b288670ed .
#
# cap:input-value-056355a5-bff5-40d3-a418-03e8db1965bc a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "E" ;
#     cap:comparesWithTargetThing "E" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-f365b3d88b69c6f7bdde5b94dfc8d518 .
#
# cap:input-value-05709264-3009-41c0-adb4-78930cf6dbdf a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "B" ;
#     cap:comparesWithTargetThing "A" ;
#     cap:hasBetterCandidate "even" ;
#     cap:hasNumericValue 1 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-f365b3d88b69c6f7bdde5b94dfc8d518 .
#
# cap:input-value-0570d035-e6bb-43e7-b321-591b685689f5 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "F" ;
#     cap:comparesWithTargetThing "F" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-46d5b36249c0e5b4e9f4e2f7ef7ecaee .
#
# cap:input-value-057935d7-692a-4779-beff-e9e3f78453b6 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "F" ;
#     cap:comparesWithTargetThing "H" ;
#     cap:hasBetterCandidate "F" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-f365b3d88b69c6f7bdde5b94dfc8d518 .
#
# cap:input-value-05869630-71fa-41fe-b508-c2398193e019 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "C" ;
#     cap:comparesWithTargetThing "H" ;
#     cap:hasBetterCandidate "H" ;
#     cap:hasNumericValue 4 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-57b127bb2f81913bbddead0094b4438e .
#
# cap:input-value-058b257d-0cec-4cb2-916c-c4beb7a293a0 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "E" ;
#     cap:comparesWithTargetThing "H" ;
#     cap:hasBetterCandidate "E" ;
#     cap:hasNumericValue 4 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-7c2ad08a1d9dc8fe65ea391c85cab251 .
#
# cap:input-value-05a4e54c-2f81-4ec3-a864-f71f74efa388 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "L" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-131d62d76f82880345bfb89aa8d8473b .
#
# cap:input-value-05b9e7a9-473b-42ff-afc3-6e3ee44fb8ba a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "A" ;
#     cap:comparesWithTargetThing "G" ;
#     cap:hasBetterCandidate "even" ;
#     cap:hasNumericValue 1 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-922c7f0e2ad6e08a1d13462b288670ed .
#
# cap:input-value-0617dee3-7153-4c18-8084-39f9be9385c6 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "H" ;
#     cap:comparesWithTargetThing "H" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-131d62d76f82880345bfb89aa8d8473b .
#
# cap:input-value-06204389-d1c9-4014-a09e-9501be10dcd6 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "A" ;
#     cap:comparesWithTargetThing "A" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-131d62d76f82880345bfb89aa8d8473b .
#
# cap:input-value-066857b7-7797-4464-ae77-d802761cb689 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "A" ;
#     cap:comparesWithTargetThing "C" ;
#     cap:hasBetterCandidate "A" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-33cc17b2ef1c119ec68af325ba1f5aab .
#
# cap:input-value-06aab2b4-63bb-423e-ab13-cf4f98c19457 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "C" ;
#     cap:comparesWithTargetThing "F" ;
#     cap:hasBetterCandidate "D" ;
#     cap:hasNumericValue 5 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-46d5b36249c0e5b4e9f4e2f7ef7ecaee .
#
# cap:input-value-06b1a57e-2767-4dfb-a21a-57ed45758d2c a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "I" ;
#     cap:comparesWithTargetThing "I" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-f365b3d88b69c6f7bdde5b94dfc8d518 .
#
# cap:input-value-06c4ae48-42c5-42c9-8419-60d129ab94e1 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "I" ;
#     cap:comparesWithTargetThing "I" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-a5933ae077ded5cd0659969993afe4f0 .
#
# cap:input-value-06d629d6-cb77-4d64-8ef2-5215fd22e64d a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "B" ;
#     cap:comparesWithTargetThing "B" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-131d62d76f82880345bfb89aa8d8473b .
#
# cap:input-value-06f30360-d792-4b1f-91d4-f3200c8e6b17 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "G" ;
#     cap:comparesWithTargetThing "A" ;
#     cap:hasBetterCandidate "G" ;
#     cap:hasNumericValue 3 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-922c7f0e2ad6e08a1d13462b288670ed .
#
# cap:input-value-06ff26d1-ffec-43ba-a85e-b0bc8424a30c a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "B" ;
#     cap:comparesWithTargetThing "B" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-7c2ad08a1d9dc8fe65ea391c85cab251 .
#
# cap:input-value-071609f0-ce57-400d-816a-7c5ed39898e6 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "G" ;
#     cap:comparesWithTargetThing "G" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-8ead6d82f482ea5d21db66d8d7f3a191 .
#
# cap:input-value-07171505-fd6c-41a3-a7ea-c52add35203a a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "A" ;
#     cap:comparesWithTargetThing "B" ;
#     cap:hasBetterCandidate "A" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-46352a35695b0cfd4ae8567d527b022d .
#
# cap:input-value-071972bd-e82d-402c-a95a-0284c24556f0 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "L" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-e1c920f35ae87bdd2146058625b6866c .
#
# cap:input-value-07203b34-77fa-4b00-9c9c-e5afa12fcb62 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "D" ;
#     cap:comparesWithTargetThing "A" ;
#     cap:hasBetterCandidate "D" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-33cc17b2ef1c119ec68af325ba1f5aab .
#
# cap:input-value-0720ba8f-eeb0-4f74-9928-1d6cd1016d2f a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "L" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-f365b3d88b69c6f7bdde5b94dfc8d518 .
#
# cap:input-value-074252c4-db7a-467a-8aac-fea90f7422ac a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "H" ;
#     cap:comparesWithTargetThing "H" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-e1c920f35ae87bdd2146058625b6866c .
#
# cap:input-value-074af7a3-284f-4a39-a862-51edcb183f22 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "H" ;
#     cap:comparesWithTargetThing "H" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-922c7f0e2ad6e08a1d13462b288670ed .
#
# cap:input-value-07a58268-c2db-4c88-ba68-b2311e0a501f a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "A" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "A" ;
#     cap:hasNumericValue 3 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-46d5b36249c0e5b4e9f4e2f7ef7ecaee .
#
# cap:input-value-07aac25e-7c41-4509-813b-88bf36b47bb4 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "H" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "H" ;
#     cap:hasNumericValue 4 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-f365b3d88b69c6f7bdde5b94dfc8d518 .
#
# cap:input-value-07bc6dde-8e5e-4e3e-bd85-f1ac7efdd367 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "F" ;
#     cap:comparesWithTargetThing "F" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-46352a35695b0cfd4ae8567d527b022d .
#
# cap:input-value-07c1e068-4657-4b32-9f29-a63a6d2c079c a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "D" ;
#     cap:comparesWithTargetThing "D" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-922c7f0e2ad6e08a1d13462b288670ed .
#
# cap:input-value-07c5f08b-13fb-4d07-a80c-07f1e8e69bb1 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "L" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-131d62d76f82880345bfb89aa8d8473b .
#
# cap:input-value-07c64960-b1fe-4d2b-80fa-7bb249df8234 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "F" ;
#     cap:comparesWithTargetThing "F" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-8ead6d82f482ea5d21db66d8d7f3a191 .
#
# cap:input-value-07c6bc83-89e5-4374-9564-86e0d83d6651 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "H" ;
#     cap:comparesWithTargetThing "A" ;
#     cap:hasBetterCandidate "L" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-57b127bb2f81913bbddead0094b4438e .
#
# cap:input-value-07cc8bd6-2af0-4553-986c-266517cc68a4 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "F" ;
#     cap:comparesWithTargetThing "F" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-57b127bb2f81913bbddead0094b4438e .
#
# cap:input-value-07da731c-4a80-47b9-818d-211be2d513da a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "B" ;
#     cap:comparesWithTargetThing "C" ;
#     cap:hasBetterCandidate "B" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-46352a35695b0cfd4ae8567d527b022d .
#
# cap:input-value-07fc7a28-84f6-4386-89a6-57b00df7e7b7 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "C" ;
#     cap:comparesWithTargetThing "A" ;
#     cap:hasBetterCandidate "I" ;
#     cap:hasNumericValue 4 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-8ead6d82f482ea5d21db66d8d7f3a191 .
#
# cap:input-value-080508f8-bd07-4999-a3a0-c743f1b6e594 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "D" ;
#     cap:comparesWithTargetThing "E" ;
#     cap:hasBetterCandidate "even" ;
#     cap:hasNumericValue 1 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-f365b3d88b69c6f7bdde5b94dfc8d518 .
#
# cap:input-value-08193aec-a3ec-48c5-82bd-92d5535da3ba a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "D" ;
#     cap:comparesWithTargetThing "A" ;
#     cap:hasBetterCandidate "even" ;
#     cap:hasNumericValue 1 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-131d62d76f82880345bfb89aa8d8473b .
#
# cap:input-value-0826f995-c765-42b3-82df-9fe21b1d6327 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "H" ;
#     cap:comparesWithTargetThing "H" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-922c7f0e2ad6e08a1d13462b288670ed .
#
# cap:input-value-082f4f80-3eab-4845-b1a1-9112aa795f40 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "B" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "H" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-f365b3d88b69c6f7bdde5b94dfc8d518 .
#
# cap:input-value-0836edb8-4edb-4f02-92c1-d7dc09e72064 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "F" ;
#     cap:comparesWithTargetThing "F" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-57b127bb2f81913bbddead0094b4438e .
#
# cap:input-value-08468809-a0ec-4bcd-b5a0-9173a3f417e9 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "B" ;
#     cap:comparesWithTargetThing "D" ;
#     cap:hasBetterCandidate "B" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-131d62d76f82880345bfb89aa8d8473b .
#
# cap:input-value-08acc5ad-f45e-4fc4-ba05-70a34ca8470f a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "A" ;
#     cap:comparesWithTargetThing "H" ;
#     cap:hasBetterCandidate "A" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-7c2ad08a1d9dc8fe65ea391c85cab251 .
#
# cap:input-value-08fef0cc-b4c2-4a71-8c23-043ffe35b6ea a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "D" ;
#     cap:comparesWithTargetThing "D" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-46d5b36249c0e5b4e9f4e2f7ef7ecaee .
#
# cap:input-value-09097441-1057-4ef8-82b3-20fb33b8c85a a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "E" ;
#     cap:comparesWithTargetThing "E" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-a5933ae077ded5cd0659969993afe4f0 .
#
# cap:input-value-0913c8dd-82ed-4d03-9112-a0c5f12b1d77 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "F" ;
#     cap:comparesWithTargetThing "F" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-f365b3d88b69c6f7bdde5b94dfc8d518 .
#
# cap:input-value-0917df39-c540-4203-b79a-2e324e2f1691 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "F" ;
#     cap:comparesWithTargetThing "F" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-922c7f0e2ad6e08a1d13462b288670ed .
#
# cap:input-value-092c6dc6-2a54-40b7-8031-a170a723b013 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "H" ;
#     cap:comparesWithTargetThing "H" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-57b127bb2f81913bbddead0094b4438e .
#
# cap:input-value-0930d6a6-4675-41fd-939c-5fe2b4ba38cb a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "E" ;
#     cap:comparesWithTargetThing "E" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-7c2ad08a1d9dc8fe65ea391c85cab251 .
#
# cap:input-value-09587501-99f0-426d-8121-07a42be57e13 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "B" ;
#     cap:comparesWithTargetThing "B" ;
#     cap:hasBetterCandidate "L" ;
#     cap:hasNumericValue 3 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
# ...
#     cap:refersToCriterion cap:criterion-57b127bb2f81913bbddead0094b4438e .
#
# cap:input-value-fee65a79-b0c7-46e5-a9d3-a0a655348712 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "I" ;
#     cap:comparesWithTargetThing "I" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-46352a35695b0cfd4ae8567d527b022d .
#
# cap:input-value-ff193edd-554f-4d43-9730-7231b95bb7bf a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "B" ;
#     cap:comparesWithTargetThing "E" ;
#     cap:hasBetterCandidate "D" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-7c2ad08a1d9dc8fe65ea391c85cab251 .
#
# cap:input-value-ff4c3c62-216d-4f5d-bf73-82a2f1757c2f a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "L" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-46d5b36249c0e5b4e9f4e2f7ef7ecaee .
#
# cap:input-value-ff5384aa-0735-43d5-af73-d10a95a242eb a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "G" ;
#     cap:comparesWithTargetThing "G" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-57b127bb2f81913bbddead0094b4438e .
#
# cap:input-value-ff5c66bc-60ac-4918-be0e-461af5bb84ee a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "G" ;
#     cap:comparesWithTargetThing "G" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-33cc17b2ef1c119ec68af325ba1f5aab .
#
# cap:input-value-ff5d14ee-606e-4e8b-a8da-6a25b0abbc73 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "D" ;
#     cap:comparesWithTargetThing "L" ;
#     cap:hasBetterCandidate "D" ;
#     cap:hasNumericValue 3 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-46d5b36249c0e5b4e9f4e2f7ef7ecaee .
#
# cap:input-value-ff641967-4ebc-4a31-a89d-4602f5238862 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "I" ;
#     cap:comparesWithTargetThing "I" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-131d62d76f82880345bfb89aa8d8473b .
#
# cap:input-value-ff8d9f97-2b36-47b7-b50a-ad4c5e4b8a4e a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "D" ;
#     cap:comparesWithTargetThing "D" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-46d5b36249c0e5b4e9f4e2f7ef7ecaee .
#
# cap:input-value-ff9575f4-5d9d-4373-9d9d-99369d793f97 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "D" ;
#     cap:comparesWithTargetThing "D" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-df27b3b081fbe0cbad4b77cf7eef114e ;
#     cap:refersToCriterion cap:criterion-922c7f0e2ad6e08a1d13462b288670ed .
#
# cap:input-value-ffc13b34-d055-4610-bde0-c347836b0ff4 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "F" ;
#     cap:comparesWithTargetThing "F" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-a5933ae077ded5cd0659969993afe4f0 .
#
# cap:input-value-ffe72f41-80c1-4026-aa6d-c55b39904f04 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "B" ;
#     cap:comparesWithTargetThing "F" ;
#     cap:hasBetterCandidate "D" ;
#     cap:hasNumericValue 2 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-e1c920f35ae87bdd2146058625b6866c .
#
# cap:input-value-ffe9df4b-845b-4991-a730-4aec4ee60537 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "G" ;
#     cap:comparesWithTargetThing "G" ;
#     cap:hasBetterCandidate "aSa" ;
#     cap:hasNumericValue 0 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-f365b3d88b69c6f7bdde5b94dfc8d518 .
#
# cap:input-value-ffedfdc7-b5d0-44ee-bd19-7371d3713e96 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "A" ;
#     cap:comparesWithTargetThing "F" ;
#     cap:hasBetterCandidate "even" ;
#     cap:hasNumericValue 1 ;
#     cap:isProvidedBy cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 ;
#     cap:refersToCriterion cap:criterion-f365b3d88b69c6f7bdde5b94dfc8d518 .
#
# cap:input-value-fffbd68d-bbd3-4a88-b45d-4360874a9a99 a cap:InputValue,
#         owl:NamedIndividual ;
#     cv:role roles:evaluator ;
#     cap:comparesSourceThing "C" ;
#     cap:comparesWithTargetThing "H" ;
#     cap:hasBetterCandidate "H" ;
#     cap:hasNumericValue 4 ;
#     cap:isProvidedBy cap:agent-a6f449d3e3204f42dbee51221ed83ae9 ;
#     cap:refersToCriterion cap:criterion-e1c920f35ae87bdd2146058625b6866c .
#
# cap:criterion-07025e0e10c183174d56042ea92de0a5 a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "3" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-0b2ce1f216d430bbf0f01011150ff0de ;
#     skos:scopeNote "Qualitative Objective Criterion"@en ;
#     cccev:hasName "13. quality index additional  IQ4"@en ;
#     cccev:hasType ct:qo .
#
# cap:criterion-0d026df263ad10d93ba513a5688a1a3b a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "1" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-0b2ce1f216d430bbf0f01011150ff0de ;
#     skos:scopeNote "Qualitative Objective Criterion"@en ;
#     cccev:hasName "13. quality index additional  IQ2"@en ;
#     cccev:hasType ct:qo .
#
# cap:criterion-1cde9c85e59224e387c807e5d906a059 a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "3" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-0b2ce1f216d430bbf0f01011150ff0de ;
#     skos:scopeNote "Qualitative Objective Criterion"@en ;
#     cccev:hasName "1. Quality aspect 12"@en ;
#     cccev:hasType ct:qo .
#
# cap:criterion-34c0bb3aef2a3bb89c46ccfcbb802c5c a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "1" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-0b2ce1f216d430bbf0f01011150ff0de ;
#     skos:scopeNote "Qualitative Objective Criterion"@en ;
#     cccev:hasName "13. quality index additional  IQ1"@en ;
#     cccev:hasType ct:qo .
#
# cap:criterion-4fee44f9198b099490652d27b5ba4552 a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "3" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-0b2ce1f216d430bbf0f01011150ff0de ;
#     skos:scopeNote "Qualitative Objective Criterion"@en ;
#     cccev:hasName "BONUS for additional voluntary add-on"@en ;
#     cccev:hasType ct:qo .
#
# cap:criterion-7c1f0498498b72a8ef0f6270124b7a5b a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "20" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-270f05b64f3e68a9b1101c1c3de738d0 ;
#     skos:scopeNote "Price Objective Criterion"@en ;
#     cccev:hasName "FIRST TYPE OF SERVICES - MANDATORY"@en ;
#     cccev:hasType ct:po .
#
# cap:criterion-b2981aa96ed545654cafdd0623fb8144 a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "20" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-270f05b64f3e68a9b1101c1c3de738d0 ;
#     skos:scopeNote "Price Objective Criterion"@en ;
#     cccev:hasName "SECOND TYPE OF SERVICES -OPTIONAL"@en ;
#     cccev:hasType ct:po .
#
# cap:criterion-b94da418318331e2acb1694b2aefba36 a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "2" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-0b2ce1f216d430bbf0f01011150ff0de ;
#     skos:scopeNote "Qualitative Objective Criterion"@en ;
#     cccev:hasName "13. quality index additional  IQ5"@en ;
#     cccev:hasType ct:qo .
#
# cap:criterion-c4c8a97423ae02c51fa728c122761d2e a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "3" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-0b2ce1f216d430bbf0f01011150ff0de ;
#     skos:scopeNote "Qualitative Objective Criterion"@en ;
#     cccev:hasName "13. quality index additional  IQ6"@en ;
#     cccev:hasType ct:qo .
#
# cap:criterion-fa104d5272006e350d0e0f0cd34f6975 a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "2" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-0b2ce1f216d430bbf0f01011150ff0de ;
#     skos:scopeNote "Qualitative Objective Criterion"@en ;
#     cccev:hasName "13. quality index additional  IQ3"@en ;
#     cccev:hasType ct:qo .
#
# cap:criterion-dimension-270f05b64f3e68a9b1101c1c3de738d0 a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasChild cap:criterion-7c1f0498498b72a8ef0f6270124b7a5b,
#         cap:criterion-b2981aa96ed545654cafdd0623fb8144 ;
#     cap:hasMaximumScore "40" ;
#     cap:hasMinimumScore 1 ;
#     skos:scopeNote "Price Dimension"@en ;
#     cccev:hasName "Price Dimension - TOTAL SCORE - SIMPLE"@en ;
#     cccev:hasType ct:pd .
#
# cap:criterion-dimension-0b2ce1f216d430bbf0f01011150ff0de a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasChild cap:criterion-07025e0e10c183174d56042ea92de0a5,
#         cap:criterion-0d026df263ad10d93ba513a5688a1a3b,
#         cap:criterion-131d62d76f82880345bfb89aa8d8473b,
#         cap:criterion-1cde9c85e59224e387c807e5d906a059,
#         cap:criterion-33cc17b2ef1c119ec68af325ba1f5aab,
#         cap:criterion-34c0bb3aef2a3bb89c46ccfcbb802c5c,
#         cap:criterion-46352a35695b0cfd4ae8567d527b022d,
#         cap:criterion-46d5b36249c0e5b4e9f4e2f7ef7ecaee,
#         cap:criterion-4fee44f9198b099490652d27b5ba4552,
#         cap:criterion-57b127bb2f81913bbddead0094b4438e,
#         cap:criterion-7c2ad08a1d9dc8fe65ea391c85cab251,
#         cap:criterion-8ead6d82f482ea5d21db66d8d7f3a191,
#         cap:criterion-922c7f0e2ad6e08a1d13462b288670ed,
#         cap:criterion-a5933ae077ded5cd0659969993afe4f0,
#         cap:criterion-b94da418318331e2acb1694b2aefba36,
#         cap:criterion-c4c8a97423ae02c51fa728c122761d2e,
#         cap:criterion-e1c920f35ae87bdd2146058625b6866c,
#         cap:criterion-f365b3d88b69c6f7bdde5b94dfc8d518,
#         cap:criterion-fa104d5272006e350d0e0f0cd34f6975 ;
#     cap:hasMaximumScore "60" ;
#     cap:hasMinimumScore 1 ;
#     skos:scopeNote "Quality Dimension"@en ;
#     cccev:hasName "Quality Dimension for Lot n - Award Criterion and score per tender lot - TOTAL SCORE - SIMPLE"@en ;
#     cccev:hasType ct:qd .
#
# cap:criterion-131d62d76f82880345bfb89aa8d8473b a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "3" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-0b2ce1f216d430bbf0f01011150ff0de ;
#     skos:scopeNote "Qualitative Subjective Criterion"@en ;
#     cccev:hasName "1. Quality aspect 11"@en ;
#     cccev:hasType ct:qs .
#
# cap:criterion-33cc17b2ef1c119ec68af325ba1f5aab a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "4" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-0b2ce1f216d430bbf0f01011150ff0de ;
#     skos:scopeNote "Qualitative Subjective Criterion"@en ;
#     cccev:hasName "1. Quality aspect 7"@en ;
#     cccev:hasType ct:qs .
#
# cap:criterion-46352a35695b0cfd4ae8567d527b022d a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "3" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-0b2ce1f216d430bbf0f01011150ff0de ;
#     skos:scopeNote "Qualitative Subjective Criterion"@en ;
#     cccev:hasName "1. Quality aspect 3"@en ;
#     cccev:hasType ct:qs .
#
# cap:criterion-46d5b36249c0e5b4e9f4e2f7ef7ecaee a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "3" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-0b2ce1f216d430bbf0f01011150ff0de ;
#     skos:scopeNote "Qualitative Subjective Criterion"@en ;
#     cccev:hasName "1. Quality aspect 2"@en ;
#     cccev:hasType ct:qs .
#
# cap:criterion-57b127bb2f81913bbddead0094b4438e a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "4" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-0b2ce1f216d430bbf0f01011150ff0de ;
#     skos:scopeNote "Qualitative Subjective Criterion"@en ;
#     cccev:hasName "1. Quality aspect 6"@en ;
#     cccev:hasType ct:qs .
#
# cap:criterion-7c2ad08a1d9dc8fe65ea391c85cab251 a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "4" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-0b2ce1f216d430bbf0f01011150ff0de ;
#     skos:scopeNote "Qualitative Subjective Criterion"@en ;
#     cccev:hasName "1. Quality aspect 9"@en ;
#     cccev:hasType ct:qs .
#
# cap:criterion-8ead6d82f482ea5d21db66d8d7f3a191 a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "4" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-0b2ce1f216d430bbf0f01011150ff0de ;
#     skos:scopeNote "Qualitative Subjective Criterion"@en ;
#     cccev:hasName "1. Quality aspect 5"@en ;
#     cccev:hasType ct:qs .
#
# cap:criterion-922c7f0e2ad6e08a1d13462b288670ed a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "3" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-0b2ce1f216d430bbf0f01011150ff0de ;
#     skos:scopeNote "Qualitative Subjective Criterion"@en ;
#     cccev:hasName "1. Quality aspect 4"@en ;
#     cccev:hasType ct:qs .
#
# cap:criterion-a5933ae077ded5cd0659969993afe4f0 a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "4" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-0b2ce1f216d430bbf0f01011150ff0de ;
#     skos:scopeNote "Qualitative Subjective Criterion"@en ;
#     cccev:hasName "1. Quality aspect 8"@en ;
#     cccev:hasType ct:qs .
#
# cap:criterion-e1c920f35ae87bdd2146058625b6866c a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "6" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-0b2ce1f216d430bbf0f01011150ff0de ;
#     skos:scopeNote "Qualitative Subjective Criterion"@en ;
#     cccev:hasName "1. Quality aspect 1"@en ;
#     cccev:hasType ct:qs .
#
# cap:criterion-f365b3d88b69c6f7bdde5b94dfc8d518 a epo:AwardCriterion,
#         owl:NamedIndividual ;
#     cap:hasMaximumScore "4" ;
#     cap:hasMinimumScore 1 ;
#     cap:hasParent cap:criterion-dimension-0b2ce1f216d430bbf0f01011150ff0de ;
#     skos:scopeNote "Qualitative Subjective Criterion"@en ;
#     cccev:hasName "1. Quality aspect 10"@en ;
#     cccev:hasType ct:qs .
#
# cap:agent-65dd1315c8bfe99ac085cbddf3dabaa5 a owl:NamedIndividual,
#         foaf:Person ;
#     foaf:familyName "Mc Alister"@en ;
#     foaf:givenName "Bob"@en .
#
# cap:agent-a6f449d3e3204f42dbee51221ed83ae9 a owl:NamedIndividual,
#         foaf:Person ;
#     foaf:familyName "Mauricius"@en ;
#     foaf:givenName "Alice"@en .
#
# cap:agent-df27b3b081fbe0cbad4b77cf7eef114e a owl:NamedIndividual,
#         foaf:Person ;
#     foaf:familyName "Casanova"@en ;
#     foaf:givenName "Martha"@en .
#
# roles:evaluator a skos:Concept ;
#     skos:broader roles:Role ;
#     skos:prefLabel "Evaluator"@en .

# %% [markdown]
# <h2>Step #3: Store the graph into the Graph Store</h2>

# %% [markdown]
# <h4>We first connect to the Graph Store.</h4>
# <p><b><u>Note</u></b>: This show uses a local GraphDB store and a repository named 'cav-pilot'. In your case you will have to have a Graph Store available, either locally or remotely, and re-configure the code (see the function 'connect()' inside the
# module 'store.py'.</p>

# %%
sparql = store.connect()

# %% [markdown]
# <h4>We then drop the current 'named graph', if any.</h4>

# %%
store.drop(sparql)
# Out:
# DROP done

# %% [markdown]
# <h4>Now we load the graph into the Graph Store (again, many triples are to be inserted, so wait a bit, please...)</h4>

# %%
store.insert(g, sparql)
# Out:
# INSERT done

# %% [markdown]
# <h2>Step #4: Query the Graph Store and retrieve the data per criterion, evaluator, etc.</h4>

# %% [markdown]
# <h4>4.1. Let us retrieve now the data from the Graph Store.</h4>
#
# 4.1.1. The <b><u>User Story</u></b> for this operation goes as this:
#
# <p><div align="center"><i>I, as the algorithm calculating and ranking which is the winner of Lot1 of the procurement procedure X, want to get all input values introduced by all evaluators for this procedure's lot and concerning exclusively 'Qualitative Subjective Criteria', so I can assess the deviations between the evaluators' decisions.</i></div></p>
#
# 4.1.2. The <b><u>Competency Question</u></b> goes like this:
# <p><div align="center"><i>Retrieve all the input values assigned by all evaluators to 'Qualitative Subjective Criteria', as well as the information related to the input value.</i></div></p>

# %% [markdown]
# 4.1.3. And the corresponding <b><u>SPARQL Query</u></b> like this:
#
#     PREFIX cap: <http://data.europa.eu/w21/2c930c7b-5e2f-4954-8522-bd3411339d6c/extension/cap#>
#     PREFIX owl: <http://www.w3.org/2002/07/owl#>
#     PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
#     PREFIX cccev: <https://data.europe.eu/semanticassets/ns/cv/cccev_v2.0.0#>
#     PREFIX foaf: <http://xmlns.com/foaf/0.1/>
#     PREFIX ct: <http://data.europa.eu/w21/2c930c7b-5e2f-4954-8522-bd3411339d6c/resource/criterion-type#>
#     PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
#     SELECT 	?input (concat(?givenName, " ", ?familyName) as ?agent) ?source ?target ?winner ?value (str(?crit) as ?criterion) (str(?cObj) as ?cid)
#             ?maxscore ?note
#     FROM cap:
#     WHERE {
#         ?input rdf:type cap:InputValue ;
#            cap:comparesSourceThing ?source ;
#            cap:comparesWithTargetThing ?target ;
#            cap:hasBetterCandidate ?winner ;
#            cap:hasNumericValue ?value ;
#            cap:isProvidedBy ?agentObj;
#            cap:refersToCriterion ?cObj .
#         ?cObj cccev:hasName ?crit ;
#                    cap:hasMaximumScore ?maxscore ;
#                    skos:scopeNote ?note .
#         ?agentObj foaf:givenName ?givenName ;
#                   foaf:familyName ?familyName .
#
#         FILTER EXISTS {?cObj cccev:hasType ct:qs}
#         FILTER (?source != ?target && ?value != 0)
#
#     } ORDER BY ?agent

# %% [markdown]
# <h4>4.2. So, let us execute this SPARQL query...</h4>

# %%
results = q._query(sparql)

# %% [markdown]
# 4.2.1 The results are obtained as a ... <b>BIG</b> .. JSON object:

# %%
print(results)
# Out:
# {'head': {'vars': ['input', 'agent', 'source', 'target', 'winner', 'value', 'criterion', 'cid', 'maxscore', 'note']}, 'results': {'bindings': [{'input': {'type': 'uri', 'value': 'http://data.europa.eu/w21/2c930c7b-5e2f-4954-8522-bd3411339d6c/extension/cap#input-value-05a6e36a-8a17-417c-90f0-65cbe8d5ff42'}, 'note': {'xml:lang': 'en', 'type': 'literal', 'value': 'Qualitative Subjective Criterion'}, 'agent': {'type': 'literal', 'value': 'Alice Mauricius'}, 'winner': {'type': 'literal', 'value': 'even'}, 'criterion': {'type': 'literal', 'value': '1. Quality aspect 11'}, 'source': {'type': 'literal', 'value': 'D'}, 'maxscore': {'type': 'literal', 'value': '3'}, 'value': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '1'}, 'target': {'type': 'literal', 'value': 'L'}, 'cid': {'type': 'literal', 'value': 'http://data.europa.eu/w21/2c930c7b-5e2f-4954-8522-bd3411339d6c/extension/cap#criterion-131d62d76f82880345bfb89aa8d8473b'}}, {'input': {'type': 'uri', 'value': 'http://data.europa.eu/w21/2c930c7b-5e2f-4954-8522-bd3411339d6c/extension/cap#input-value-11037884-9a79-4d60-a74e-ad14c54acaf1'}, 'note': {'xml:lang': 'en', 'type': 'literal', 'value': 'Qualitative Subjective Criterion'}, 'agent': {'type': 'literal', 'value': 'Alice Mauricius'}, 'winner': {'type': 'literal', 'value': 'A'}, 'criterion': {'type': 'literal', 'value': '1. Quality aspect 11'}, 'source': {'type': 'literal', 'value': 'A'}, 'maxscore': {'type': 'literal', 'value': '3'}, 'value': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '2'}, 'target': {'type': 'literal', 'value': 'H'}, 'cid': {'type': 'literal', 'value': 'http://data.europa.eu/w21/2c930c7b-5e2f-4954-8522-bd3411339d6c/extension/cap#criterion-131d62d76f82880345bfb89aa8d8473b'}}, {'input': {'type': 'uri', 'value': 'http://data.europa.eu/w21/2c930c7b-5e2f-4954-8522-bd3411339d6c/extension/cap#input-value-1cab5d47-8be2-4e5f-8438-58e124597eae'}, 'note': {'xml:lang': 'en', 'type': 'literal', 'value': 'Qualitative Subjective Criterion'}, 'agent': {'type': 'literal', 'value': 'Alice Mauricius'}, 'winner': {'type': 'literal', 'value': 'L'}, 'criterion': {'type': 'literal', 'value': '1. Quality aspect 11'}, 'source': {'type': 'literal', 'value': 'G'}, 'maxscore': {'type': 'literal', 'value': '3'}, 'value': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '2'}, 'target': {'type': 'literal', 'value': 'B'}, 'cid': {'type': 'literal', 'value': 'http://data.europa.eu/w21/2c930c7b-5e2f-4954-8522-bd3411339d6c/extension/cap#criterion-131d62d76f82880345bfb89aa8d8473b'}}, {'input': {'type': 'uri', 'value': 'http://data.europa.eu/w21/2c930c7b-5e2f-4954-8522-bd3411339d6c/extension/cap#input-value-3e43fed8-5360-4fcc-be99-43762bc6542a'}, 'note': {'xml:lang': 'en', 'type': 'literal', 'value': 'Qualitative Subjective Criterion'}, 'agent': {'type': 'literal', 'value': 'Alice Mauricius'}, 'winner': {'type': 'literal', 'value': 'even'}, 'criterion': {'type': 'literal', 'value': '1. Quality aspect 11'}, 'source': {'type': 'literal', 'value': 'A'}, 'maxscore': {'type': 'literal', 'value': '3'}, 'value': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '1'}, 'target': {'type': 'literal', 'value': 'B'}, 'cid': {'type': 'literal', 'value': 'http://data.europa.eu/w21/2c930c7b-5e2f-4954-8522-bd3411339d6c/extension/cap#criterion-131d62d76f82880345bfb89aa8d8473b'}}, {'input': {'type': 'uri', 'value': 'http://data.europa.eu/w21/2c930c7b-5e2f-4954-8522-bd3411339d6c/extension/cap#input-value-415bd0d9-8543-4761-9a00-63680a2d1b68'}, 'note': {'xml:lang': 'en', 'type': 'literal', 'value': 'Qualitative Subjective Criterion'}, 'agent': {'type': 'literal', 'value': 'Alice Mauricius'}, 'winner': {'type': 'literal', 'value': 'D'}, 'criterion': {'type': 'literal', 'value': '1. Quality aspect 11'}, 'source': {'type': 'literal', 'value': 'D'}, 'maxscore': {'type': 'literal', 'value': '3'}, 'value': {'datatype': 'http://ww ...

# %% [markdown]
# <h2>Step #5: Based on these results, we rank the tender-lots submitted by the tenderers</h2>

# %% [markdown]
# <h4>5.1. Let us get the J+ and P+, according to the ELECTRE-II, phase I algorithm:</h4>

# %%
j = electre.get_j(results)
print(j)

# %% [markdown]
# This function returns a collection of criteria and per each criterion, it's <u>maximum score</u>, the <u>source tender lot</u> and the <u>target tender-lot</u> represented both with one letter (A-L, without J nor K), the <u>best tender-lot</u> resulting from comparing source and target, it's <u>sign</u> (+, = or -), the name of the <u>evaluator</u>, the <u>value</u> assigned by the evaluator as a result of the tender-pair-evaluation, and its weight (resulting from dividing its value by the maximum score).
#
# Next we show you an example for one positive criterion:

# %%
criterion = 'criterion-131d62d76f82880345bfb89aa8d8473b'
print('Criterion: {}'.format(criterion.split('-')[1]))
print('maximum score: {}'.format(j[criterion]['max_score']))
print('source tender-lot: {}'.format(j[criterion]['jw'][4][0]))
print('target tender-lot: {}'.format(j[criterion]['jw'][4][1]))
print('best tender-lot pair: {}'.format(j[criterion]['jw'][4][2]))
print('best tender-lot sign: {}'.format(j[criterion]['jw'][4][3]))
print('evaluator: {}'.format(j[criterion]['jw'][4][4]))
print('evaluator\'s assigned value : {}'.format(j[criterion]['jw'][4][5]))
print('relative weight (value / max_score) {}'.format(j[criterion]['jw'][4][6]))
